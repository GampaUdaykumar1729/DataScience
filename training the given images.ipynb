# %%
import cv2
import imutils.paths as paths

import face_recognition
import pickle
import os
dataset = "D:\\series\\dataset\\" # path of the data set 
module = "D:\\series\\encoding1.pickle" # were u want to store the pickle file 

imagepaths = list(paths.list_images(dataset))
knownEncodings = []
knownNames = []
for (i, imagePath) in enumerate(imagepaths):
    print("[INFO] processing image {}/{}".format(i + 1,len(imagepaths)))
    name = imagePath.split(os.path.sep)[-2]
    image = cv2.imread(imagePath)
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)	
    boxes = face_recognition.face_locations(rgb, model= "hog")
    encodings = face_recognition.face_encodings(rgb, boxes)
    for encoding in encodings:
        knownEncodings.append(encoding)
        knownNames.append(name)
        print("[INFO] serializing encodings...")
        data = {"encodings": knownEncodings, "names": knownNames}
        output = open(module, "wb") 
        pickle.dump(data, output)
        output.close()
# Out:
# [INFO] processing image 1/82
# [INFO] processing image 2/82
# [INFO] processing image 3/82
# [INFO] processing image 4/82
# [INFO] processing image 5/82
# [INFO] processing image 6/82
# [INFO] processing image 7/82
# [INFO] processing image 8/82
# [INFO] processing image 9/82
# [INFO] processing image 10/82
# [INFO] serializing encodings...
# [INFO] processing image 11/82
# [INFO] processing image 12/82
# [INFO] serializing encodings...
# [INFO] processing image 13/82
# [INFO] serializing encodings...
# [INFO] processing image 14/82
# [INFO] processing image 15/82
# [INFO] processing image 16/82
# [INFO] processing image 17/82
# [INFO] processing image 18/82
# [INFO] processing image 19/82
# [INFO] processing image 20/82
# [INFO] processing image 21/82
# [INFO] processing image 22/82
# [INFO] processing image 23/82
# [INFO] serializing encodings...
# [INFO] processing image 24/82
# [INFO] processing image 25/82
# [INFO] processing image 26/82
# [INFO] processing image 27/82
# [INFO] processing image 28/82
# [INFO] processing image 29/82
# [INFO] processing image 30/82
# [INFO] serializing encodings...
# [INFO] processing image 31/82
# [INFO] serializing encodings...
# [INFO] processing image 32/82
# [INFO] serializing encodings...
# [INFO] processing image 33/82
# [INFO] serializing encodings...
# [INFO] processing image 34/82
# [INFO] serializing encodings...
# [INFO] processing image 35/82
# [INFO] serializing encodings...
# [INFO] processing image 36/82
# [INFO] processing image 37/82
# [INFO] serializing encodings...
# [INFO] processing image 38/82
# [INFO] processing image 39/82
# [INFO] processing image 40/82
# [INFO] processing image 41/82
# [INFO] processing image 42/82
# [INFO] serializing encodings...
# [INFO] processing image 43/82
# [INFO] serializing encodings...
# [INFO] processing image 44/82
# [INFO] serializing encodings...
# [INFO] processing image 45/82
# [INFO] serializing encodings...
# [INFO] processing image 46/82
# [INFO] serializing encodings...
# [INFO] processing image 47/82
# [INFO] serializing encodings...
# [INFO] processing image 48/82
# [INFO] serializing encodings...
# [INFO] processing image 49/82
# [INFO] serializing encodings...
# [INFO] processing image 50/82
# [INFO] serializing encodings...
# [INFO] processing image 51/82
# [INFO] serializing encodings...
# [INFO] processing image 52/82
# [INFO] serializing encodings...
# [INFO] processing image 53/82
# [INFO] serializing encodings...
# [INFO] processing image 54/82
# [INFO] serializing encodings...
# [INFO] processing image 55/82
# [INFO] serializing encodings...
# [INFO] processing image 56/82
# [INFO] serializing encodings...
# [INFO] processing image 57/82
# [INFO] serializing encodings...
# [INFO] processing image 58/82
# [INFO] serializing encodings...
# [INFO] processing image 59/82
# [INFO] serializing encodings...
# [INFO] processing image 60/82
# [INFO] serializing encodings...
# [INFO] processing image 61/82
# [INFO] serializing encodings...
# [INFO] processing image 62/82
# [INFO] serializing encodings...
# [INFO] processing image 63/82
# [INFO] serializing encodings...
# [INFO] processing image 64/82
# [INFO] serializing encodings...
# [INFO] processing image 65/82
# [INFO] serializing encodings...
# [INFO] processing image 66/82
# [INFO] serializing encodings...
# [INFO] processing image 67/82
# [INFO] serializing encodings...
# [INFO] processing image 68/82
# [INFO] serializing encodings...
# [INFO] processing image 69/82
# [INFO] serializing encodings...
# [INFO] processing image 70/82
# [INFO] serializing encodings...
# [INFO] processing image 71/82
# [INFO] serializing encodings...
# [INFO] processing image 72/82
# [INFO] serializing encodings...
# [INFO] processing image 73/82
# [INFO] serializing encodings...
# [INFO] processing image 74/82
# [INFO] serializing encodings...
# [INFO] processing image 75/82
# [INFO] serializing encodings...
# [INFO] processing image 76/82
# [INFO] serializing encodings...
# [INFO] processing image 77/82
# [INFO] serializing encodings...
# [INFO] processing image 78/82
# [INFO] serializing encodings...
# [INFO] processing image 79/82
# [INFO] serializing encodings...
# [INFO] processing image 80/82
# [INFO] serializing encodings...
# [INFO] processing image 81/82
# [INFO] serializing encodings...
# [INFO] processing image 82/82
# [INFO] serializing encodings...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\UDAY'
